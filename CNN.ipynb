# %%
import matplotlib.pyplot as plt

# %run MNIST_readImages.ipynb
# %run MNIST_readLabels.ipynb
# %run Layers.ipynb

Img_Train = read_images('train')
Label_Train = read_labels('train')

Img_Test = read_images('test')
Label_Test = read_labels('test')

class Network():
    def __init__(self):
        tau = 0.01 # Learning rate
        self.layers = []
        self.layers.append(Convolution(1, 3, 3, 1))
        self.layers.append(ReLU())
        self.layers.append(Pooling(2))
        self.layers.append(FullyConnected(3, 10, tau))
        self.layers.append(Softmax())
        
        
    #     self.layers.append(ReLU())
    #     self.layers.append(Pooling(2))
    #     self.layers.append(FullyConnected())

    def train_network():
        return None

    def run_network(self):

        img = Img_Train[0,:,:]
        img_f1 = Img_Train[0,16:19,16:19]
        img_f2 = Img_Train[0,14:17, 14:17]

        imgf = [img_f1, img_f2]
        for f in imgf:
            out = self.layers[0].forward_prop(img, f)
            print(out.shape)
            for i in out:
                plt.imshow(i)
                plt.show()

        relu = []
        for i in range(0, len(out)):
            relu.append(self.layers[1].forward_prop(out[i]))
    
        print("RELU")
        for i in relu:
            plt.imshow(i)
            plt.show()
            
            
        print("POOL")
        pool = []
        for i in range(0, len(relu)):
            pool.append(self.layers[2].forward_prop(relu[i]))
            
        for i in pool:
            plt.imshow(i[0])
            plt.show()
            
        fc = self.layers[3].forward(pool)
        return None

    def test_error():
        return None

CNN = Network()
CNN.run_network()
# Out:
# 2051 60000 28 28
# (60000,)
# 5
# 2051 10000 28 28
# (10000,)
# 7
# 26 26
# (3, 26, 26)
# 26 26
# (3, 26, 26)
# RELU
# POOL
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-a67150c58147> in <module>()
#      69
#      70 CNN = Network()
# ---> 71 CNN.run_network()
#
# <ipython-input-52-a67150c58147> in run_network(self)
#      62             plt.show()
#      63
# ---> 64         fc = self.layers[3].forward(pool)
#      65         return None
#      66
#
# <ipython-input-52-53c93dc0bb5a> in forward(self, inputs)
#     265     def forward(self, inputs):
#     266         self.inputs = inputs
# --> 267         return np.dot(self.inputs, self.weights) + self.bias.T
#     268
#     269     def backward(self, dy):
#
# ValueError: setting an array element with a sequence.
